# %% [markdown]
# # Importing libraries and loading the dataset

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models #provides functions for building and working with neural networks
import matplotlib.pyplot as plt
import numpy as np

data = '/Users/rohanshenoy/Downloads/A,B,CNNS_with_Tim/veggie_heap_training'
test = '/Users/rohanshenoy/Downloads/A,B,CNNS_with_Tim/veggie_heap_testing'

# %% [markdown]
# # splitting training data into training and validation subsets to validate training data

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(256, 256),
  batch_size=32
  )

val_ds = tf.keras.utils.image_dataset_from_directory(
  data,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(256, 256),
  batch_size=32
  )
# Out:
# Found 9835 files belonging to 12 classes.
# Using 7868 files for training.
# Found 9835 files belonging to 12 classes.
# Using 1967 files for validation.

# %% [markdown]
# # Storing test dataset

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
  test,
  seed=123,
  image_size=(256,256),
  batch_size=32
)
# Out:
# Found 2424 files belonging to 12 classes.

# %% [markdown]
# # Creating an iterator over the training dataset and getting a batch of images and their corresponding labels

# %%
image_batch, label_batch = next(iter(train_ds))
class_names = train_ds.class_names

# %%
image_batch
# Out:
# <tf.Tensor: shape=(32, 256, 256, 3), dtype=float32, numpy=
# array([[[[142.   , 121.   , 116.   ],
#          [138.   , 117.   , 112.   ],
#          [137.   , 116.   , 111.   ],
#          ...,
#          [127.   , 104.   ,  98.   ],
#          [ 94.   ,  71.   ,  65.   ],
#          [117.   ,  94.   ,  88.   ]],
#
#         [[147.   , 126.   , 121.   ],
#          [ 99.   ,  78.   ,  73.   ],
#          [118.   ,  97.   ,  92.   ],
#          ...,
#          [134.   , 111.   , 105.   ],
#          [113.   ,  90.   ,  84.   ],
#          [100.   ,  77.   ,  71.   ]],
#
#         [[132.   , 111.   , 106.   ],
#          [117.   ,  96.   ,  91.   ],
#          [124.   , 103.   ,  98.   ],
#          ...,
#          [128.   , 105.   ,  99.   ],
#          [139.   , 116.   , 110.   ],
#          [ 97.   ,  74.   ,  68.   ]],
#
#         ...,
#
#         [[198.   , 189.   , 182.   ],
#          [202.   , 193.   , 186.   ],
#          [206.   , 197.   , 190.   ],
#          ...,
#          [196.   , 183.   , 175.   ],
#          [193.   , 180.   , 172.   ],
#          [188.   , 175.   , 167.   ]],
#
#         [[202.   , 193.   , 186.   ],
#          [204.   , 195.   , 188.   ],
#          [206.   , 197.   , 190.   ],
#          ...,
#          [192.   , 179.   , 171.   ],
#          [192.   , 179.   , 171.   ],
#          [190.   , 177.   , 169.   ]],
#
#         [[209.   , 200.   , 193.   ],
#          [209.   , 200.   , 193.   ],
#          [209.   , 200.   , 193.   ],
#          ...,
#          [190.   , 177.   , 169.   ],
#          [192.   , 179.   , 171.   ],
#          [195.   , 182.   , 174.   ]]],
#
#
#        [[[ 12.   ,  11.   ,   6.   ],
#          [ 12.   ,  11.   ,   6.   ],
#          [ 11.   ,  10.   ,   5.   ],
#          ...,
#          [ 35.   ,  27.   ,  24.   ],
#          [ 34.   ,  26.   ,  23.   ],
#          [ 34.   ,  26.   ,  23.   ]],
#
#         [[ 12.   ,  11.   ,   6.   ],
#          [ 12.   ,  11.   ,   6.   ],
#          [ 11.   ,  10.   ,   5.   ],
#          ...,
#          [ 35.625,  27.625,  24.625],
#          [ 34.625,  26.625,  23.625],
#          [ 34.   ,  26.   ,  23.   ]],
#
#         [[ 13.125,  11.375,   6.375],
#          [ 12.75 ,  11.   ,   6.   ],
#          [ 12.125,  10.375,   5.375],
#          ...,
#          [ 36.   ,  28.   ,  25.   ],
#          [ 34.625,  26.625,  23.625],
#          [ 33.625,  25.625,  22.625]],
#
#         ...,
#
#         [[ 67.   ,  68.   ,  63.   ],
#          [ 68.   ,  69.   ,  64.   ],
#          [ 68.   ,  69.   ,  64.   ],
#          ...,
#          [ 57.   ,  54.   ,  39.   ],
#          [ 57.   ,  54.   ,  39.   ],
#          [ 57.   ,  54.   ,  39.   ]],
#
#         [[ 67.375,  68.375,  63.375],
#          [ 68.   ,  69.   ,  64.   ],
#          [ 68.   ,  69.   ,  64.   ],
#          ...,
#          [ 57.   ,  54.   ,  39.   ],
#          [ 57.   ,  54.   ,  39.   ],
#          [ 56.625,  53.625,  38.625]],
#
#         [[ 68.   ,  69.   ,  64.   ],
#          [ 68.   ,  69.   ,  64.   ],
#          [ 68.   ,  69.   ,  64.   ],
#          ...,
#          [ 57.   ,  54.   ,  39.   ],
#          [ 57.   ,  54.   ,  39.   ],
#          [ 56.   ,  53.   ,  38.   ]]],
#
#
#        [[[127.   , 131.   , 166.   ],
#          [126.   , 130.   , 165.   ],
#          [129.   , 133.   , 168.   ],
#          ...,
#          [146.   , 142.   , 165.   ],
#          [164.   , 160.   , 183.   ],
#          [181.   , 177.   , 200.   ]],
#
#         [[129.   , 133.   , 168.   ],
#          [128.   , 132.   , 167.   ],
#          [130.   , 134.   , 169.   ],
#          ...,
#          [143.   , 139.   , 162.   ],
#          [113.   , 109.   , 132.   ],
#          [123.   , 119.   , 142.   ]],
#
#         [[131.   , 135.   , 170.   ],
#          [130.   , 134.   , 169.   ],
#          [132.   , 136.   , 171.   ],
#          ...,
#          [141.   , 137.   , 160.   ],
#          [135.   , 131.   , 154.   ],
#          [165.   , 161.   , 184.   ]],
#
#         ...,
#
#         [[124.   , 127.   , 162.   ],
#          [124.   , 127.   , 162.   ],
#          [124.   , 127.   , 162.   ],
#          ...,
#          [ 43.   ,  52.   ,  81.   ],
#          [ 41.   ,  50.   ,  79.   ],
#          [ 37.   ,  46.   ,  75.   ]],
#
#         [[122.   , 125.   , 160.   ],
#          [123.   , 126.   , 161.   ],
#          [124.   , 127.   , 162.   ],
#          ...,
#          [ 43.   ,  52.   ,  81.   ],
#          [ 43.   ,  52.   ,  81.   ],
#          [ 46.   ,  55.   ,  84.   ]],
#
#         [[119.   , 122.   , 157.   ],
#          [120.   , 123.   , 158.   ],
#          [121.   , 124.   , 159.   ],
#          ...,
#          [ 32.   ,  41.   ,  70.   ],
#          [ 30.   ,  39.   ,  68.   ],
#          [ 36.   ,  45.   ,  74.   ]]],
#
#
#        ...,
#
#
#        [[[198.   , 188.   , 197.   ],
#          [203.   , 193.   , 202.   ],
#          [180.   , 170.   , 179.   ],
#          ...,
#          [173.   , 164.   , 169.   ],
#          [148.   , 139.   , 144.   ],
#          [218.   , 209.   , 214.   ]],
#
#         [[173.   , 163.   , 172.   ],
#          [145.   , 135.   , 144.   ],
#          [182.   , 172.   , 181.   ],
#          ...,
#          [201.   , 192.   , 197.   ],
#          [202.   , 193.   , 198.   ],
#          [181.   , 172.   , 177.   ]],
#
#         [[210.   , 200.   , 209.   ],
#          [184.   , 174.   , 183.   ],
#          [202.   , 192.   , 201.   ],
#          ...,
#          [220.   , 211.   , 216.   ],
#          [200.   , 191.   , 196.   ],
#          [173.   , 164.   , 169.   ]],
#
#         ...,
#
#         [[172.   , 164.   , 177.   ],
#          [170.   , 162.   , 175.   ],
#          [171.   , 163.   , 176.   ],
#          ...,
#          [182.   , 174.   , 187.   ],
#          [180.   , 172.   , 185.   ],
#          [184.   , 176.   , 189.   ]],
#
#         [[171.   , 163.   , 176.   ],
#          [167.   , 159.   , 172.   ],
#          [168.   , 160.   , 173.   ],
#          ...,
#          [184.   , 176.   , 189.   ],
#          [182.   , 174.   , 187.   ],
#          [185.   , 177.   , 190.   ]],
#
#         [[172.   , 164.   , 177.   ],
#          [167.   , 159.   , 172.   ],
#          [167.   , 159.   , 172.   ],
#          ...,
#          [184.   , 176.   , 189.   ],
#          [183.   , 175.   , 188.   ],
#          [185.   , 177.   , 190.   ]]],
#
#
#        [[[198.   , 192.   , 194.   ],
#          [177.   , 171.   , 173.   ],
#          [187.   , 181.   , 183.   ],
#          ...,
#          [197.   , 191.   , 195.   ],
#          [194.   , 188.   , 192.   ],
#          [195.   , 189.   , 193.   ]],
#
#         [[203.   , 197.   , 199.   ],
#          [194.   , 188.   , 190.   ],
#          [186.   , 180.   , 182.   ],
#          ...,
#          [198.   , 192.   , 196.   ],
#          [195.   , 189.   , 193.   ],
#          [197.   , 191.   , 195.   ]],
#
#         [[179.   , 173.   , 175.   ],
#          [194.   , 188.   , 190.   ],
#          [177.   , 171.   , 173.   ],
#          ...,
#          [193.   , 187.   , 191.   ],
#          [191.   , 185.   , 189.   ],
#          [194.   , 188.   , 192.   ]],
#
#         ...,
#
#         [[141.   , 130.   , 136.   ],
#          [132.   , 121.   , 127.   ],
#          [115.   , 104.   , 110.   ],
#          ...,
#          [148.   , 141.   , 148.   ],
#          [127.   , 120.   , 127.   ],
#          [162.   , 155.   , 162.   ]],
#
#         [[123.   , 112.   , 118.   ],
#          [133.   , 122.   , 128.   ],
#          [130.   , 119.   , 125.   ],
#          ...,
#          [139.   , 132.   , 139.   ],
#          [135.   , 128.   , 135.   ],
#          [168.   , 161.   , 168.   ]],
#
#         [[144.   , 133.   , 139.   ],
#          [126.   , 115.   , 121.   ],
#          [122.   , 111.   , 117.   ],
#          ...,
#          [119.   , 112.   , 119.   ],
#          [122.   , 115.   , 122.   ],
#          [154.   , 147.   , 154.   ]]],
#
#
#        [[[141.   , 148.   , 177.   ],
#          [142.   , 149.   , 178.   ],
#          [142.   , 149.   , 177.   ],
#          ...,
#          [128.   , 138.   , 174.   ],
#          [128.   , 138.   , 174.   ],
#          [127.   , 137.   , 173.   ]],
#
#         [[141.   , 148.   , 177.   ],
#          [142.   , 149.   , 178.   ],
#          [142.   , 149.   , 177.   ],
#          ...,
#          [128.   , 138.   , 174.   ],
#          [128.   , 138.   , 174.   ],
#          [127.   , 137.   , 173.   ]],
#
#         [[141.   , 148.   , 177.   ],
#          [141.625, 148.625, 177.625],
#          [142.   , 149.   , 177.   ],
#          ...,
#          [128.   , 138.   , 174.   ],
#          [127.625, 137.625, 173.625],
#          [127.   , 137.   , 173.   ]],
#
#         ...,
#
#         [[ 49.75 ,  49.75 ,  49.75 ],
#          [ 49.125,  49.125,  49.125],
#          [ 49.5  ,  49.5  ,  49.5  ],
#          ...,
#          [ 32.625,  41.625,  40.625],
#          [ 32.625,  41.625,  40.625],
#          [ 32.625,  41.625,  40.625]],
#
#         [[ 49.   ,  49.   ,  49.   ],
#          [ 48.   ,  48.   ,  48.   ],
#          [ 48.375,  48.375,  48.375],
#          ...,
#          [ 33.75 ,  42.75 ,  41.75 ],
#          [ 33.75 ,  42.75 ,  41.75 ],
#          [ 33.75 ,  42.75 ,  41.75 ]],
#
#         [[ 49.   ,  49.   ,  49.   ],
#          [ 48.   ,  48.   ,  48.   ],
#          [ 49.   ,  49.   ,  49.   ],
#          ...,
#          [ 35.   ,  44.   ,  43.   ],
#          [ 35.   ,  44.   ,  43.   ],
#          [ 35.   ,  44.   ,  43.   ]]]], dtype=float32)>

# %%
class_names
# Out:
# ["Apatosaur Aphie's Apples",
#  "Bluplocephalus Bob's Blueberries",
#  "Cherizinoasaur Cher's Cherries",
#  "Corythosaurus Cory's Corn",
#  "Grapthorina Greta's Grapes",
#  "Pachycephalosaurus Perry's Peaches",
#  "Pepteranodon Pep's Peppers",
#  "Potoceratops Pott's Potatoes",
#  "Rhaspdodon Ribery's Raspberries",
#  "Stribecosaurus Stan's Strawberries",
#  "Thyreosaur Tim's Thyme",
#  'vacation_photos']

# %%
#we inspect the dataset and visualize whether the images and verify whether the images,labels have loaded correctly or not
plt.figure(figsize=(14, 14))
for i in range(12):
  ax = plt.subplot(4, 4, i + 1)
  plt.imshow(image_batch[i].numpy().astype("uint8"))
  label = label_batch[i]
  plt.title(class_names[label])
  plt.axis("off")

# %% [markdown]
# # CNN model

# %%
cnn = models.Sequential([

    layers.Rescaling(1./255),

    # convolutional layers
    layers.Conv2D(filters = 128, activation = 'relu', kernel_size = (3,3), input_shape = (256,256,3)),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(filters = 128, activation = 'relu', kernel_size = (3,3), input_shape = (256,256,3)),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(filters = 128, activation = 'relu', kernel_size = (3,3), input_shape = (256,256,3)),
    layers.MaxPooling2D((2,2)),

    # dense or fully connected layers
    layers.Flatten(),
    layers.Dense(64, activation = 'relu'),
    layers.Dense(12, activation = 'softmax'),
])

# %% [markdown]
# # Compiling the model by adding loss fn and performing backpropogation

# %%
cnn.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics = ['accuracy'])

# %% [markdown]
# # train of the model on training dataset, we evaluate the performance on the validation dataset

# %%
cnn.fit(train_ds,
  validation_data=val_ds,
  epochs=3)
# Out:
# Epoch 1/3
# 246/246 [==============================] - 917s 4s/step - loss: 0.9774 - accuracy: 0.6777 - val_loss: 0.3355 - val_accuracy: 0.8973
# Epoch 2/3
# 246/246 [==============================] - 1124s 5s/step - loss: 0.2891 - accuracy: 0.9089 - val_loss: 0.2270 - val_accuracy: 0.9232
# Epoch 3/3
# 246/246 [==============================] - 1052s 4s/step - loss: 0.1737 - accuracy: 0.9450 - val_loss: 0.2558 - val_accuracy: 0.9248

# %% [markdown]
# # evaluating the model on the test dataset

# %%
loss, accuracy = cnn.evaluate(test_ds)


print(f"loss = {loss}\nAccuracy = {accuracy*100}")
# Out:
# 76/76 [==============================] - 66s 866ms/step - loss: 2.4332 - accuracy: 0.5891
# loss = 2.43318510055542
# Accuracy = 58.91088843345642

# %%
# Get predictions for the test set
y_pred = np.argmax(cnn.predict(test_ds), axis=1)
y_true = np.concatenate([y for x, y in test_ds], axis=0)
# Out:
# 76/76 [==============================] - 68s 890ms/step

# %%
y_pred #the predicted class labels for each image
# Out:
# array([ 3, 11,  0, ...,  0,  0,  0])

# %%
y_true #the actual class labels for each image
# Out:
# array([ 5,  2, 11, ...,  2,  8,  3], dtype=int32)

# %% [markdown]
# # Printing a confusion matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()
